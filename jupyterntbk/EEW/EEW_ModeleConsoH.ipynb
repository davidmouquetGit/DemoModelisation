# %%
file_data = "/content/drive/My Drive/EEW/Data/donnees_horaires_narbonne.csv"
import pandas as pd
data = pd.read_csv(file_data)

dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
data = pd.read_csv(file_data,parse_dates=True,date_parser=dateparse,low_memory = False,index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-61aedf0c8547> in <module>()
#       1 file_data = "/content/drive/My Drive/EEW/Data/donnees_horaires_narbonne.csv"
#       2 import pandas as pd
# ----> 3 data = pd.read_csv(file_data)
#       4
#       5 dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     222         oauth_prompt,
# ...

# %%
data.dropna(inplace=True)
data.drop(columns=['MES_CHENAL_OXYDATION_F1_1', 'MES_CHENAL_OXYDATION_F1_2','MES_CHENAL_OXYDATION_FILE_2_1','MES_CHENAL_OXYDATION_FILE_2_2','MODULE_BD1'], inplace=True)

# %%
dataset = data.values
	# split into input (X) and output (y) variables
X = dataset[:, :-1]
y = dataset[:,-1]

# %%
X.shape
# Out:
# (3672, 53)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# define feature selection
fs = SelectKBest(score_func=f_regression, k=53)
# apply feature selection
X_selected = fs.fit_transform(X, y)

# %%
var_name = list(data.columns)
var_name.pop()
df_score = pd.DataFrame(data={'Variable':var_name,'Score':fs.scores_})
import plotly.express as px

fig = px.bar(df_score, x='Variable', y='Score')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c0392c5c-a63a-42e4-96b3-b5a18b8e1b11" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c0392c5c-a63a-42e4-96b3-b5a18b8e1b11")) {
#                     Plotly.newPlot(
#                         'c0392c5c-a63a-42e4-96b3-b5a18b8e1b11',
# ...

# %%
var_name = list(data.columns)
var_name.pop()
df_score = pd.DataFrame(data={'Variable':var_name,'Score':fs.pvalues_})
import plotly.express as px

fig = px.bar(df_score, x='Variable', y='Score')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b62257c3-86da-40a6-865d-3a8b31cdab60" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b62257c3-86da-40a6-865d-3a8b31cdab60")) {
#                     Plotly.newPlot(
#                         'b62257c3-86da-40a6-865d-3a8b31cdab60',
# ...

# %%
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import numpy as np
scaler = MinMaxScaler()

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                   random_state = 0)

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

linlasso = Lasso(alpha=0.1, max_iter = 10000).fit(X_train_scaled, y_train)
linreg   = LinearRegression().fit(X_train_scaled, y_train)
print('Crime dataset')
print('lasso regression linear model intercept: {}'
     .format(linlasso.intercept_))
print('lasso regression linear model coeff:\n{}'
     .format(linlasso.coef_))
print('Non-zero features: {}'
     .format(np.sum(linlasso.coef_ != 0)))
print('R-squared score (training): {:.3f}'
     .format(linlasso.score(X_train_scaled, y_train)))
print('R-squared score (test): {:.3f}\n'
     .format(linlasso.score(X_test_scaled, y_test)))
print('Features with non-zero weight (sorted by absolute magnitude):')

print('Lin R-squared score (training): {:.3f}'
     .format(linreg.score(X_train_scaled, y_train)))
print('Lin R-squared score (test): {:.3f}\n'
     .format(linreg.score(X_test_scaled, y_test)))
print('Features with non-zero weight (sorted by absolute magnitude):')
# Out:
# Crime dataset
# lasso regression linear model intercept: 111.30791090760223
# lasso regression linear model coeff:
# [-0.00000000e+00 -0.00000000e+00 -3.99268624e+00  2.18988418e+00
#   3.67036113e+00 -0.00000000e+00 -8.38969148e-02  3.92092787e+01
#   2.70770423e+01 -3.82148875e+01  0.00000000e+00  6.68259373e+01
#  -0.00000000e+00 -0.00000000e+00  2.49160372e+01  7.14319616e+01
#   1.00569673e+00  0.00000000e+00  0.00000000e+00 -7.90906361e-01
#   0.00000000e+00  1.70320347e+00  0.00000000e+00  3.46537748e+00
#   1.01727706e+01 -8.11434880e+01  3.43453806e+01  0.00000000e+00
#  -3.98888719e+00  4.50192111e+00  6.07520390e+01 -0.00000000e+00
#   6.02630123e+00  3.22701946e+00 -0.00000000e+00 -1.10196060e+00
#  -1.10365394e+00  3.09880403e+00  4.77305081e+01  7.18897713e+00
#   8.63023875e+01  0.00000000e+00  3.17180525e+01  5.25259219e+01
#   2.45284411e+00  0.00000000e+00  5.55243000e+01  3.31186687e+01
#   3.10032613e+01 -0.00000000e+00  0.00000000e+00  7.33778786e-01
# ...

# %%
var_name = list(data.columns)
var_name.pop()
df_score = pd.DataFrame(data={'Variable':var_name,'Poids':linreg.coef_})
import plotly.express as px

fig = px.bar(df_score, x='Variable', y='Poids')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2c80d758-6b22-4807-b1d9-3755fd22a88d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2c80d758-6b22-4807-b1d9-3755fd22a88d")) {
#                     Plotly.newPlot(
#                         '2c80d758-6b22-4807-b1d9-3755fd22a88d',
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import numpy as np

parameters = {'alpha':[0.01, 0.05,0.1,0.5,1,2,3,5,10,50,10]}
mod = Lasso(max_iter = 10000)
clf = GridSearchCV(mod, parameters)
clf.fit(X_train_scaled, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 677.4772878673393, tolerance: 624.3324712563676
# GridSearchCV(cv=None, error_score=nan,
#              estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=10000, normalize=False, positive=False,
#                              precompute=False, random_state=None,
#                              selection='cyclic', tol=0.0001, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'alpha': [0.01, 0.05, 0.1, 0.5, 1, 2, 3, 5, 10, 50,
#                                    10]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
