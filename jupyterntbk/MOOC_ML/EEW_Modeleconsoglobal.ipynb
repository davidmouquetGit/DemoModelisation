# %%
file_data = "/content/drive/My Drive/PROJETS/EE-Waternamics/Data/donnees_journalieres_narbonne.csv"
import pandas as pd
data = pd.read_csv(file_data)

dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
data = pd.read_csv(file_data,parse_dates=True,date_parser=dateparse,low_memory = False,na_values=' ',index_col=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   """

# %%
Var_label = ['OPUS_QJ__EB_SYS__m³/j',      
'OPUS_Ch_DCO_traitee',          
'OPUS_Ch_MEST_traitee',           
'OPUS_Ch_NGL_traitee','EVELER_P_ACT_KW']

df_Var = data[Var_label]
df_Var.dropna(inplace=True)

dataset = df_Var.values
	# split into input (X) and output (y) variables
X = dataset[:, :-1]
y = dataset[:,-1]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
X.shape
# Out:
# (722, 4)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# define feature selection
fs = SelectKBest(score_func=f_regression, k=4)
# apply feature selection
X_selected = fs.fit_transform(X, y)

# %%
fs.scores_
# Out:
# array([ 2.8038458 , 24.99557855,  4.44248484,  0.59740232])

# %%
fs.pvalues_
# Out:
# array([9.44727697e-02, 7.22381036e-07, 3.54002888e-02, 4.39824538e-01])

# %%
from scipy.stats.stats import pearsonr

CR = pearsonr(X[:,2],y)

# %%
CR
# Out:
# (0.07830888159913248, 0.035400288810826304)
